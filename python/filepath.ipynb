# %%
# create a new directory

import os

# os.makedirs('my_directory')
print(os.getcwd())
# Out:
# c:\Users\shrav\OneDrive\Desktop\Youtube\ml_course\python

# %%
# Join path

folder = 'my_folder'
file=  'cars_collection.txt'

print(os.path.join(os.getcwd(),folder, file))
# Out:
# c:\Users\shrav\OneDrive\Desktop\Youtube\ml_course\python\my_folder\cars_collection.txt

# %%
# check path exists or not

file_path = 'example.txt'

if os.path.exists(file_path):
    print('The path exists')
else:
    print("the path doesn't exists")
# Out:
# The path exists

# %%
# check if it's file or directory

file_path = 'my_directory'

if os.path.isfile(file_path):
    print("it's a file")
elif os.path.isdir(file_path):
    print("it's a dir")
else:
    print('some other data')
# Out:
# some other data

# %%
# getting the absolute path


file_path = 'example.txt'

print(os.path.abspath(file_path))
# Out:
# c:\Users\shrav\OneDrive\Desktop\Youtube\ml_course\python\example.txt
