# %%
# Basic python syntax
# variables in  python
# data types in python
# operators in python
#

# %%
# Basic Python Syntax
# Single line comment / multi-line comment
# Case Sensitivity

a = 10
b = 20
print(a + b)


first_name = "Tom "
last_name = "Holland"
full_name = first_name + last_name
print(full_name.)
# Out:
# 30
# Tom Holland

# %%
#Indentation in python
# Python uses indentation to define blocks of code. 

name = "Robert Downey Jr."

age = 50

if age > 30:
    print("Robert is older than 30")
else:
    print("Robert is younger than 30")
# Out:
# Robert is older than 30

# %%
# Data types in python

# Basic data types 
# Integers 
# Floating Point Numbers
# Strings
# Booleans

# Additional data types
# Lists
# Tuples
# Dictionaries
# Sets

# type casting

name = "Shravan"
type(name)
# Out:
# str

# %%
age = 27
type(age)
# Out:
# int

# %%
height = 6.0
type(height)
# Out:
# float

# %%
is_male = True
# type(is_male)

boolean_value = bool(True)
type(boolean_value)
# Out:
# bool

# %%
name = "Shravan" + str(27)
print(name)
# Out:
# Shravan27

# %%
# single Line Continuation
# Multi-line Statements in single line

x=10
y=77

print(x, y)


a=10;b=20;c=30;d=55
print(a,b,c,d)

total_sum = (10 + 20 +
             50+ 60+
             77 + 99)

print(total_sum)
# Out:
# 10 77
# 10 20 30 55
# 316

# %%
# Variables in Python, Variable Naming Rules, Variable Assignment, Multiple Assignment, Variable Types, Type Conversion, Type Casting, Constants in Python

# %%
# Operators 
# Arithmetic Operators
# +, -, *, /, %, **, //

# Comparison Operators
# ==, !=, >, <, >=, <=

# Logical Operators
# and, or, not

# %%
# Arithmetic Operators
# +, -, *, /, %, **, //


a = 20
b = 2

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a % b)
print(a ** b)
print(a // b)
# Out:
# 22
# 18
# 40
# 10.0
# 0
# 400
# 10

# %%
a = 6
b = 4

print(a // b)
# Out:
# 1

# %%
a = 6
b = 4

print(a % b)
# Out:
# 2

# %%
# Comparison Operators
# ==, !=, >, <, >=, <=

a = 10
b = 4

# print(a == b)
# print(a != b)


name1 = "Shravan"
name2 = "ShravaN"

print(name1 == name2)
# Out:
# False

# %%
# Logical Operators
# and, or, not

a = 10
b = 20

print(a and b)
# Out:
# 20

# %%
# Logical Operators
# and, or, not

a = True
b = True

# print(a and b)
# print(a or b)

bool_value = False

print(not bool_value)
# Out:
# True
