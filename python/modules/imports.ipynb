# %%
import package.maths

print(package.maths.addition(2,5))
# Out:
# 7

# %%
from package.maths import *

print(addition(22,8))
# Out:
# 30

# %%
from package.maths import substraction

print(substraction(3,1))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from package.maths import substraction
#       2
#       3 print(substraction(3,1))
#
# ImportError: cannot import name 'substraction' from 'package.maths' (c:\Users\shrav\OneDrive\Desktop\Youtube\ml_course\python\modules\package\maths.py)
