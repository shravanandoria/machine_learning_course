# %% [markdown]
# The Python Standard Library is a vast collection of built-in modules and packages that come pre-installed with every Python distribution

# %%
# Array
import array

my_arr = array.array('i', [1,2,3,4])
print(my_arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
# random
import random

rand_num = random.randint(1,10)
choice = random.choice(['homelander', 'spiderman', 'ironman'])
print(rand_num)
print(choice)
# Out:
# 9
# homelander

# %%
# os

import os

print(os.getcwd())

name = "shravan_dir"
os.mkdir(name)
# Out:
# c:\Users\shrav\OneDrive\Desktop\Youtube\ml_course\python\modules

# %%
# High level operations on files

# shutil
import shutil

shutil.copy('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
# data serialization
# json
import json

data = {'name': 'shravan', 'age': 27}
parsed_json = json.dumps(data)
print(parsed_json)
print(type(parsed_json))

parsed_data = json.loads(parsed_json)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "shravan", "age": 27}
# <class 'str'>
# {'name': 'shravan', 'age': 27}
# <class 'dict'>

# %%
# csv
import csv

with open('example.csv', mode='w', newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['shravan', 27])
    
with open('example.csv', mode='r') as file:
    reader=csv.reader(file)
    for data in reader:
        print(data)
# Out:
# ['name', 'age']
# ['shravan', '27']

# %%
# datetime

from datetime import datetime, timedelta

now=datetime.now()
print(now)

yesterday= now - timedelta(days=1)
print(yesterday)
# Out:
# 2026-09-23 20:19:31.856794
# 2026-09-22 20:19:31.856794

# %%
# time

import time

print(time.time())

time.sleep(2)

print(time.time())
# Out:
# 1790175064.50238
# 1790175066.5029585

# %%
# regular expression
import re

pattern = r'\d+'
text = 'there are 30 footballs'
result = re.search(pattern, text)
print(result.group())
# Out:
# 30
